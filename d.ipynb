# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack


f=np.linspace(0,4000,100) #Hz
#amp = np.flip(np.linspace(1, 10, 10))  # m
dt=0.0001
t=np.arange(0,10,dt) #sec
x = 0
for i in range(0,f.size):
    x = x+np.sin(2*np.pi*f[i]*t)

fft=np.abs(scipy.fftpack.fft(x))*2/len(x)


freq = np.fft.fftfreq(x.size, d=dt)

freq = freq[freq >= 0]
fft = fft[:int(fft.size/2)]
#x=np.fft.fftshift(x)
# fft=np.abs(np.fft.fft(x))*2/len(x)
# fft = np.fft.fftshift(fft)  # Shift zero freq to center
# freq = np.fft.fftshift(freq)

plt.figure(2)
plt.plot(freq,fft)
# plt.axis([0, 1000, 0, 10])
plt.grid(True)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack

fs = 1000
T = 1/fs
L = 1500
t = np.arange(0, L-1, 1)*T
x=0
f = np.linspace(0, 100, 5)
for i in range(0, f.size):
    x = x+np.sin(2*np.pi*f[i]*t)
p2=abs(np.fft.fft(x)/L)
p1=p2[1:int(L/2)+1]
p1[2:] = 2*p1[2:]
#f = fs*np.[0:(L/2)]/L
plt.plot(p1)
